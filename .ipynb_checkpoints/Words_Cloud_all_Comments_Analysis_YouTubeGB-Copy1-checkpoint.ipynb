# %%
#!pip install nltk

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

#nltk.download('averaged_perceptron_tagger')
#nltk.download('words')
#nltk.download('maxent_ne_chunker')
#plt.style.use('ggplot')
import nltk
import pickle
from wordcloud import WordCloud
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('Cleaned_comments_witth Label.csv')

df.drop_duplicates().dropna()
# Out:
#            video_id  label                                      clean_comment  \
# 0       jt2OHQh0HoQ  False  it s more accurate to call it the m 1000 becau...
# 1       jt2OHQh0HoQ  False                 to be there with a samsung phone n
# 2       jt2OHQh0HoQ  False  thank gosh a place i can watch it without havi...
# 3       jt2OHQh0HoQ  False  what happened to the home button on the iphone...
# 4       jt2OHQh0HoQ  False  power is the disease care is the cure keep car...
# ...             ...    ...                                                ...
# 358019  lLN1FwiqGwc  False                                 gasp n gasp n gasp
# 358020  lLN1FwiqGwc  False                      yeah but does everybody float
# 358021  lLN1FwiqGwc  False                                 that meme me d ace
# 358022  lLN1FwiqGwc  False                        10 43 is that miles ups hur
# 358023  lLN1FwiqGwc  False                                wa ha nwa ha nwa ha
#
#         Label
# 0           0
# 1           0
# 2           0
# 3           0
# 4           0
# ...       ...
# 358019      0
# 358020      0
# 358021      0
# 358022      0
# 358023      0
#
# [356429 rows x 4 columns]

# %%
df.groupby('video_id')['clean_comment'].count().sort_values(ascending=False) # finding the top 1 video id has the most comments
# Out:
# video_id
# LunHybOKIjU    1130
# Q0CbN8sfihY    1101
# r9-DM9uBtVI     950
# t3AVtQkEHaE     941
# uE6iQ5HiJts     919
#                ...
# AnCYGSMxWzk       2
# aVatBKfRUZ8       2
# un75cup_EKs       2
# srr_7fM-hL4       1
# YMDGPSWWA18       1
# Name: clean_comment, Length: 1692, dtype: int64

# %%
#df.sort_values(by = 'likes',ascending =False).head(10)
df_like_replies= pd.read_csv('Centimental_Analysis_YouTubeGB_results.csv')

# df_like_replies = df_like_dislikes[['likes', 'replies', 'Analysis_comments']]
# df_like_replies#.reset_index(inplace=True)
# df_like_replies= df_like_dislikes.rename(columns = {'index':'video_id'})
df_like_replies.drop_duplicates().dropna()
# Out:
#            video_id                                       comment_text  likes  \
# 0       jt2OHQh0HoQ  It's more accurate to call it the M+ (1000) be...      0
# 1       jt2OHQh0HoQ           To be there with a samsung phone\n______      1
# 2       jt2OHQh0HoQ  Thank gosh, a place I can watch it without hav...      0
# 3       jt2OHQh0HoQ  What happened to the home button on the iPhone...      0
# 4       jt2OHQh0HoQ  Power is the disease._ Care is the cure._ Keep...      0
# ...             ...                                                ...    ...
# 718448  XQFeShp6UIY          Exploit used = Not World__ First. Simple.      2
# 718449  XQFeShp6UIY  Some exotics in Destiny have hidden perks. The...      3
# 718450  XQFeShp6UIY  Why is there a race if it's literally the same...      1
# 718451  XQFeShp6UIY  Who the fuck cares about some stupid heavy gli...      0
# 718452  XQFeShp6UIY  So using mechanics built into the raid is chea...      0
#
#         replies  negative_comments  neutral_comments  positive_comments  \
# 0             0              0.310             0.690              0.000
# 1             0              0.310             0.690              0.000
# 2             0              0.310             0.690              0.000
# 3             0              0.310             0.690              0.000
# 4             0              0.310             0.690              0.000
# ...         ...                ...               ...                ...
# 718448        2              0.171             0.667              0.162
# 718449        4              0.171             0.667              0.162
# 718450        3              0.171             0.667              0.162
# 718451        2              0.171             0.667              0.162
# 718452        1              0.171             0.667              0.162
#
#         compound_comments Analysis_comments
# 0                 -0.5574          Negative
# 1                 -0.5574          Negative
# 2                 -0.5574          Negative
# 3                 -0.5574          Negative
# 4                 -0.5574          Negative
# ...                   ...               ...
# 718448            -0.0516          Negative
# 718449            -0.0516          Negative
# 718450            -0.0516          Negative
# 718451            -0.0516          Negative
# 718452            -0.0516          Negative
#
# [407736 rows x 9 columns]

# %%
df_like_replies.groupby('video_id')['comment_text'].count().sort_values(ascending=False) # finding the top 1 video id has the most comments
# Out:
# video_id
# #NAME?         10318
# LunHybOKIjU     1200
# Q0CbN8sfihY     1199
# t3AVtQkEHaE     1100
# r9-DM9uBtVI     1050
#                ...
# 9lx41ak9GWk        4
# 35zynOrkvMk        3
# srr_7fM-hL4        2
# utPFb_tNARo        2
# jNb0vRORLAw        2
# Name: comment_text, Length: 1669, dtype: int64

# %%
df_like_replies.loc['video_id'] = "LunHybOKIjU"
df_like_replies=df_like_replies[['video_id','comment_text','likes','replies','Analysis_comments']]
df_like_replies.drop_duplicates(inplace=True)
df_like_replies.dropna(inplace=True)

# %%
#df=df.merge(df_like_dislikes,on='video_id')

# %%
df_like_replies.shape
# Out:
# (407737, 5)

# %% [markdown]
# # Comments annalysis on Top1 videoId

# %% [markdown]
# # Sentiment Analysis
# ## Step 1. VADER Setiment Scoring, we will use SentimentIntensityAnalyzer
#
#     this uses a "bag of words"approach
#     1.stop words are removed
#     2. each word is scored and combined to a total score.

# %%
from nltk.sentiment import SentimentIntensityAnalyzer
from tqdm.notebook import tqdm

nltk.download('vader_lexicon')
sia = SentimentIntensityAnalyzer()

# %%
str(df_like_replies['comment_text']).encode('utf-8')
# Out:
# b"0           It's more accurate to call it the M+ (1000) be...\n1                    To be there with a samsung phone\\n______\n2           Thank gosh, a place I can watch it without hav...\n3           What happened to the home button on the iPhone...\n4           Power is the disease._ Care is the cure._ Keep...\n                                  ...                        \n718449      Some exotics in Destiny have hidden perks. The...\n718450      Why is there a race if it's literally the same...\n718451      Who the fuck cares about some stupid heavy gli...\n718452      So using mechanics built into the raid is chea...\nvideo_id                                          LunHybOKIjU\nName: comment_text, Length: 407737, dtype: object"

# %% [markdown]
# # run the polarity score to the entire df

# %%
#topid_name=df.query('video_id == "#NAME?"')
topid=df_like_replies.query('video_id== "LunHybOKIjU"')[['comment_text','likes','replies','Analysis_comments']] # finding the top 1 video id has the most comments
topid # now we have topid thathas most commnets and we can anaysis how his/her audiance feel about his videos.
# Out:
#                                                comment_text        likes  \
# 543732    I see a lot of comrades in this section. How i...            0
# 543733    Take some more medication and hang out with ch...            0
# 543734    Eminem the Caucasian Tupac. Always speaking ab...            0
# 543735    Dayyyum i thought __ry me a river_ was the whi...            0
# 543736            Trump will send a nasty tweet and ban rap            1
# ...                                                     ...          ...
# 544928                                              faginem            0
# 544929                            GARBAGE! #MAGA2020_____わ_            0
# 544930    Eminem you're old dude you're simply just not ...            0
# 544931    https://youtu.be/hdWT4CipytE\nWrestling fan snaps            1
# video_id                                        LunHybOKIjU  LunHybOKIjU
#
#               replies Analysis_comments
# 543732              0          Positive
# 543733              0          Positive
# 543734              0          Positive
# 543735              0          Positive
# 543736              0          Positive
# ...               ...               ...
# 544928              0          Positive
# 544929              0          Positive
# 544930              1          Positive
# 544931              1          Positive
# video_id  LunHybOKIjU       LunHybOKIjU
#
# [1197 rows x 4 columns]

# %%
#!pip install textblob

# %%
import os
import nltk
import re
import matplotlib.pyplot as plt
plt.style.use('fivethirtyeight')

# %%
topid.loc[:,'comment_text'] = topid.loc[:,'comment_text'].str.replace('\!','',regex=True)
topid.loc[:,'comment_text'] = topid.loc[:,'comment_text'].str.replace('\-','',regex=True)
topid.loc[:,'comment_text'] = topid.loc[:,'comment_text'].str.replace('\|','',regex=True)
topid.loc[:,'comment_text'] = topid.loc[:,'comment_text'].str.replace('https?:\/\/\S+','',regex=True)
topid.loc[:,'comment_text'] = topid.loc[:,'comment_text'].str.replace('\\','',regex=True)
topid.loc[:,'comment_text'] = topid.loc[:,'comment_text'].str.replace('_____','',regex=True)
topid.loc[:,'comment_text'] = topid.loc[:,'comment_text'].str.replace('__','',regex=True)

# df.loc[:,'title'] = df.loc[:,'title'].str.replace('\!','',regex=True)
# df.loc[:,'title'] = df.loc[:,'title'].str.replace('\-','',regex=True)
# df.loc[:,'title'] = df.loc[:,'title'].str.replace('\|','',regex=True)
# df.loc[:,'title'] = df.loc[:,'title'].str.replace('#','',regex=True)
# df.loc[:,'title'] = df.loc[:,'title'].str.replace('\+',' ',regex=True)
# df.loc[:,'title'] = df.loc[:,'title'].str.replace('\(',' ',regex=True)
# df.loc[:,'title'] = df.loc[:,'title'].str.replace('\)',' ',regex=True)
# df.loc[:,'title'] = df.loc[:,'title'].str.replace('\:',' ',regex=True)
# df.loc[:,'tags'] = df.loc[:,'tags'].str.replace('\|',' ',regex=True)
# df.loc[:,'tags'] = df.loc[:,'tags'].str.replace('\"',' ',regex=True)
# df.loc[:,'category_names'] = df.loc[:,'category_names'].str.replace('\&','',regex=True)
# df.loc[:,'category_names'] = df.loc[:,'category_names'].str.replace('\-','',regex=True)
# df.loc[:,'category_names'] = df.loc[:,'category_names'].str.replace('\/','',regex=True)
# df.head()

# %%
topid.head(100)
# Out:
#                                              comment_text likes replies  \
# 543732  I see a lot of comrades in this section. How i...     0       0
# 543733  Take some more medication and hang out with ch...     0       0
# 543734  Eminem the Caucasian Tupac. Always speaking ab...     0       0
# 543735  Dayyyum i thought ry me a river_ was the white...     0       0
# 543736          Trump will send a nasty tweet and ban rap     1       0
# ...                                                   ...   ...     ...
# 543827                              Shady is losing it...     0       0
# 543828  As much as I dont like trump. About 80% of thi...     1       1
# 543829  People are too caught up in politics and it an...     1       1
# 543830  Eminem once joked about kids dying at Columbin...     2       1
# 543831                        Eminem went in on trump ass     1       1
#
#        Analysis_comments
# 543732          Positive
# 543733          Positive
# 543734          Positive
# 543735          Positive
# 543736          Positive
# ...                  ...
# 543827          Positive
# 543828          Positive
# 543829          Positive
# 543830          Positive
# 543831          Positive
#
# [100 rows x 4 columns]

# %%
text = topid['comment_text'].to_c
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Input In [34], in <cell line: 1>()
# ----> 1 text = topid['comment_text'].to_str()
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/pandas/core/generic.py:5575, in NDFrame.__getattr__(self, name)
#    5568 if (
#    5569     name not in self._internal_names_set
#    5570     and name not in self._metadata
#    5571     and name not in self._accessors
#    5572     and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    5573 ):
#    5574     return self[name]
# -> 5575 return object.__getattribute__(self, name)
#
# AttributeError: 'Series' object has no attribute 'to_str'

# %%
wordcloud = WordCloud().generate(text)

# %%
wordcloud = WordCloud(background_color="white").generate(text)
plt.imshow(wordcloud, interpolation="bilinear")
plt.axis("off")
plt.show()

# %%
#topid.to_csv('TopID_Comments_Analysis_YouTubeGB.csv',index=False,encoding='utf-8')

# %%
#text
